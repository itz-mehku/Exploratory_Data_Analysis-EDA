# %% [markdown]
# <a href="https://colab.research.google.com/github/itz-mehku/Exploratory_Data_Analysis-EDA/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **Mini Project - 09 :** Select any dataset from **UCI Dataset Repository** and **Perform EDA**
# ---

# %% [markdown]
# # --> Perform **EDA :**

# %% [markdown]
# **# STEP 1 : IMPORT PYTHON LIBRARIES.**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **# STEP 2 : READ DATASET.**

# %%
df = pd.read_csv('used_cars_data.csv') # Read Data from the Dataset used_cars_data
df.head() # Return first 5 rows
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
df.tail(15) # Return last 15 rows
# Out:
#       S.No.                                               Name    Location  \
# 7238   7238                                    Audi A4 2.0 TDI   Hyderabad
# 7239   7239                          Honda Amaze VX AT i-Vtech   Hyderabad
# 7240   7240                            Honda Jazz 1.5 V i DTEC  Coimbatore
# 7241   7241                            BMW 5 Series 525d Sedan       Delhi
# 7242   7242                      Hyundai Grand i10 Asta Option     Kolkata
# 7243   7243                     Renault Duster 85PS Diesel RxL     Chennai
# 7244   7244                              Chevrolet Aveo 1.4 LS        Pune
# 7245   7245                              Honda Amaze S i-Vtech       Kochi
# 7246   7246                          Hyundai Grand i10 AT Asta  Coimbatore
# 7247   7247                            Hyundai EON D Lite Plus  Coimbatore
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# ...

# %%
df.shape # Return the shape of the dataset in the form of tuple(no. of rows, no. of columns)
# Out:
# (7253, 14)

# %%
df.columns # List all the columns present in the DataFrame
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
df.dtypes # Return datatype of all the columns
# Out:
# S.No.                  int64
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# dtype: object

# %% [markdown]
# **# STEP 3 : SUMMARY STATISTICS.**

# %%
df.describe() # Display Summary Statistics
# Out:
#              S.No.         Year  Kilometers_Driven        Seats        Price
# count  7253.000000  7253.000000       7.253000e+03  7200.000000  6019.000000
# mean   3626.000000  2013.365366       5.869906e+04     5.279722     9.479468
# std    2093.905084     3.254421       8.442772e+04     0.811660    11.187917
# min       0.000000  1996.000000       1.710000e+02     0.000000     0.440000
# 25%    1813.000000  2011.000000       3.400000e+04     5.000000     3.500000
# 50%    3626.000000  2014.000000       5.341600e+04     5.000000     5.640000
# 75%    5439.000000  2016.000000       7.300000e+04     5.000000     9.950000
# max    7252.000000  2019.000000       6.500000e+06    10.000000   160.000000

# %%
df.info()  # Display data types, null values, memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
df.nunique()  #  Returns the number of unique values in each column of the DataFrame
# Out:
# S.No.                7253
# Name                 2041
# Location               11
# Year                   23
# Kilometers_Driven    3660
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               450
# Engine                150
# Power                 386
# Seats                   9
# New_Price             625
# Price                1373
# dtype: int64

# %% [markdown]
# **# STEP 4 : DROPPING IRRELEVANT COLUMNS.**

# %%
df = df.drop(['Fuel_Type'] , axis =1)  # Drop irrelevant column
df.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Transmission Owner_Type     Mileage   Engine      Power  \
# 0              72000       Manual      First  26.6 km/kg   998 CC  58.16 bhp
# 1              41000       Manual      First  19.67 kmpl  1582 CC  126.2 bhp
# 2              46000       Manual      First   18.2 kmpl  1199 CC   88.7 bhp
# 3              87000       Manual      First  20.77 kmpl  1248 CC  88.76 bhp
# 4              40670    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp
#
#    Seats  New_Price  Price
# 0    5.0        NaN   1.75
# 1    5.0        NaN  12.50
# 2    5.0  8.61 Lakh   4.50
# ...

# %% [markdown]
# **# STEP 5 : RENAMING THE COLUMNS.**

# %%
df = df.rename(columns = {'Name': 'Model'}) # Rename the column 'Name' from 'Model'
df.head()
# Out:
#    S.No.                             Model    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Transmission Owner_Type     Mileage   Engine      Power  \
# 0              72000       Manual      First  26.6 km/kg   998 CC  58.16 bhp
# 1              41000       Manual      First  19.67 kmpl  1582 CC  126.2 bhp
# 2              46000       Manual      First   18.2 kmpl  1199 CC   88.7 bhp
# 3              87000       Manual      First  20.77 kmpl  1248 CC  88.76 bhp
# 4              40670    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp
#
#    Seats  New_Price  Price
# 0    5.0        NaN   1.75
# 1    5.0        NaN  12.50
# 2    5.0  8.61 Lakh   4.50
# ...

# %%
df.shape
# Out:
# (7253, 13)

# %% [markdown]
# **# STEP 6 : DROPPING THE DUPLICATE ROWS.**

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)  # Return the number of duplicated rows in the DataFrame
# Out:
# number of duplicate rows:  (0, 13)

# %%
df.isnull().sum()  # Count no. of null values in each column
# Out:
# S.No.                   0
# Model                   0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %% [markdown]
# **# STEP 7 : DROPPING THE MISSING OR NULL VALUES.**

# %%
df = df.dropna()  # Drop null values
df.count()  # Count no. of rows in each columns
# Out:
# S.No.                823
# Model                823
# Location             823
# Year                 823
# Kilometers_Driven    823
# Transmission         823
# Owner_Type           823
# Mileage              823
# Engine               823
# Power                823
# Seats                823
# New_Price            823
# Price                823
# dtype: int64

# %%
print(df.isnull().sum())  # Print null values in the each column
# Out:
# S.No.                0
# Model                0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# New_Price            0
# Price                0
# dtype: int64

# %% [markdown]
# **# STEP 8 : DETECTING OUTLIERS.**

# %%
sns.boxplot(x=df['Price'])  # Boxplot for Price column
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# **# STEP 9 : PLOT DIFFERENT FEATURES AGAINST ONE ANOTHEER.**

# %% [markdown]
# ### --> Histplot

# %%
plt.figure(figsize = (10,6))  # Plot Histplot
sns.histplot(df['Year'])
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %% [markdown]
# ### --> Scatter Plot

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = df['Year'], y = df['Price']) # Plot Scatter plot between 'Year' and 'Price'
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %% [markdown]
# ### --> Line Plot

# %%
plt.figure(figsize = (10,6))
sns.lineplot(x = df['Year'], y = df['Price'])   # Plot Line plot between 'Year' and 'Price'
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %% [markdown]
# ### --> Heat Map

# %%
plt.figure(figsize = (10,6))
c = df.corr(numeric_only= True)
sns.heatmap(c, annot = True, cmap = 'Blues')  # Plot Heat Map
# Out:
# <Axes: >

# %% [markdown]
# ---
# # **Assignment Completed**
# ---
